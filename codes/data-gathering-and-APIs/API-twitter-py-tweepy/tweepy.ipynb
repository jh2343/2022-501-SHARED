# %% [markdown]
# # Tweepy tutorial
#
# Contact: Dr. Hickman (GU) for questions
#
# **Modified from:** https://docs.tweepy.org/en/stable/getting_started.html
#
# `
# conda install -c conda-forge tweepy
# `

# %% [markdown]
# ### Authentication
#
# **content modified from:** https://docs.tweepy.org/en/v3.5.0/auth_tutorial.html
#
# Twitter requires all API requests to use OAuth for authentication.
#
# Tweepy supports oauth authentication. Authentication is handled by the tweepy.AuthHandler class.
#
# Tweepy tries to make OAuth as painless as possible for you.
#
# To begin the process we need to register our client application with Twitter.
#
# Create a new application and once you are done you should have your consumer token and secret.
#
# Keep these two handy, you’ll need them.
#
#
# **Read API keys from file**
#
# It is a good idea to save your API keys to a file that you can load into your scripts.
#
# * You can then "point" to that file anytime you need it
#
# * This keeps all your keys organized in one place, instead of being pasted into lots of different code scripts

# %%
import json 

# READ FILE
f = open("api-keys.json")
input=json.load(f); #print(input)

# LOAD KEYS INTO API
consumer_key=input["consumer_key"]    
consumer_secret=input["consumer_secret"]    
access_token=input["access_token"]    
access_token_secret=input["access_token_secret"]    
bearer_token=input["bearer_token"]

# %% [markdown]
# The next step is creating an OAuthHandler instance by passing our consumer token and secret keys.

# %%
import tweepy
# Set up Connection
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# %% [markdown]
# So now that we have our OAuthHandler equipped with an access token, we are ready for business:

# %% [markdown]
# ### Hello world example
#
# This example will download your home timeline tweets and print each one of their texts to the console.
#
# The Authentication Tutorial goes into more details about authentication.

# %%
import tweepy
print("tweepy version =",tweepy.__version__)

# Set up Connection
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

#print username
my_user_name=api.verify_credentials().screen_name
print("username=",my_user_name)

# Returns the 20 most recent statuses, including retweets, 
# posted by the authenticating user and that user’s friends. 
public_tweets = api.home_timeline()

# Print tweets to screen
for tweet in public_tweets:
    print(tweet.text)
# Out:
# tweepy version = 4.10.1
# username= DrH2343
# This is just another tweet to test the API, hello again from tweeter
# This is just a text to test the API, hello from tweeter

# %% [markdown]
# **API**
#
# The API class (tweepy.API) provides access to the entire twitter RESTful API methods.
#
# Each method can accept various parameters and return responses.
#
# For more information about these methods please refer to the following
# https://docs.tweepy.org/en/stable/api.html#api-reference
#
# **Models**
#
# When we invoke an API method most of the time it will return a Tweepy model class instance.
#
# This will contain the data returned from Twitter which we can then use inside our application.
#
# For example the following code returns to us an User model:

# %% [markdown]
# ### Twitter search
#
# Returns a collection of relevant Tweets matching a specified query.
#
# **Option-1**

# %%
import requests 

# Set up Connection
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# Define search twitter function
def search_twitter(query, tweet_fields, bearer_token = bearer_token):
    headers = {"Authorization": "Bearer {}".format(bearer_token)}

    url = "https://api.twitter.com/2/tweets/search/recent?query={}&{}".format(query, tweet_fields)
    
    print("--------------",url,"--------------")
    response = requests.request("GET", url, headers=headers)
    #print(response.status_code)
    # print(response.text)

    if response.status_code != 200:
        raise Exception(response.status_code, response.text)
    return response.json()

json_response = search_twitter(query="new york", tweet_fields="tweet.fields=text,author_id,created_at", bearer_token=bearer_token)

print(json.dumps(json_response, indent=4, sort_keys=True))
# Out:
# -------------- https://api.twitter.com/2/tweets/search/recent?query=new york&tweet.fields=text,author_id,created_at --------------
# {
#     "data": [
#         {
#             "author_id": "190544112",
#             "created_at": "2022-09-08T18:43:48.000Z",
#             "id": "1567946821980282881",
#             "text": "RT @THiddlestonMx: Tom Hiddleston en el 50 aniversario de Ralph Lauren en la New York Fashion Week. Septiembre 7, 2018 \n#HaceCuatroA\u00f1os #Ra\u2026"
#         },
#         {
#             "author_id": "949617649150984192",
#             "created_at": "2022-09-08T18:43:48.000Z",
#             "id": "1567946821955371009",
#             "text": "New York'ta \u0130rlandal\u0131 bir grup \"prostitute died\" (fahi\u015fe \u00f6ld\u00fc) diye \u015fark\u0131 s\u00f6yledi Krali\u00e7eyi Elizabeth \u00f6ld\u00fc diye. \u015eampanya falan patlatt\u0131lar. Sonra \u0130ngiliz oldu\u011funu tahmin etti\u011fim bir grup bunlara sald\u0131rd\u0131. Polis t\u00fcm \u0130ngilizleri g\u00f6zalt\u0131na ald\u0131. Hakikaten \u00f6zg\u00fcrl\u00fckler \u00fclkesiymi\u015f. \ud83d\ude0b"
#         },
#         {
#             "author_id": "1195159050071072768",
#             "created_at": "2022-09-08T18:43:47.000Z",
#             "id": "1567946820541906944",
#             "text": "RT @hugolowell: Happening now: Steve Bannon, handcuffed, is making an initial appearance in court in New York on money laundering and consp\u2026"
#         },
#         {
#             "author_id": "2398945895",
#             "created_at": "2022-09-08T18:43:47.000Z",
#             "id": "1567946820004810752",
#             "text": "@ian693 NEW YORK CITY!!!!"
#         },
#         {
#             "author_id": "1522549777463975937",
#             "created_at": "2022-09-08T18:43:47.000Z",
#             "id": "1567946819405074432",
#             "text": "RT @Harry_Styles: Love On Tour. New York City X. September, 2022. https://t.co/u1vhXMTTWc"
#         },
#         {
#             "author_id": "2759775154",
#             "created_at": "2022-09-08T18:43:47.000Z",
#             "id": "1567946819014885379",
#             "text": "RT @templewildcats: New Story: Reunited with cousin York, running back Brundage brings production to Temple https://t.co/rJOQnV8UEV"
#         },
#         {
#             "author_id": "1321034651042041856",
#             "created_at": "2022-09-08T18:43:46.000Z",
#             "id": "1567946817039638528",
#             "text": "RT @hugolowell: Happening now: Steve Bannon, handcuffed, is making an initial appearance in court in New York on money laundering and consp\u2026"
#         },
#         {
#             "author_id": "14282848",
#             "created_at": "2022-09-08T18:43:46.000Z",
#             "id": "1567946816116690946",
#             "text": "RT @hugolowell: Happening now: Steve Bannon, handcuffed, is making an initial appearance in court in New York on money laundering and consp\u2026"
#         },
#         {
#             "author_id": "1173670840220696576",
#             "created_at": "2022-09-08T18:43:46.000Z",
#             "id": "1567946815869173760",
#             "text": "RT @Harry_Styles: Love On Tour. New York City X. September, 2022. https://t.co/u1vhXMTTWc"
#         },
#         {
#             "author_id": "253226315",
#             "created_at": "2022-09-08T18:43:46.000Z",
#             "id": "1567946813600137219",
#             "text": "RT @hugolowell: Happening now: Steve Bannon, handcuffed, is making an initial appearance in court in New York on money laundering and consp\u2026"
#         }
#     ],
#     "meta": {
#         "newest_id": "1567946821980282881",
#         "next_token": "b26v89c19zqg8o3fpz8mukx3mftg7cxfm4xqrh2muqj5p",
#         "oldest_id": "1567946813600137219",
#         "result_count": 10
#     }
# }

# %% [markdown]
# **Option-2**
#
# Please note that Twitter’s search service and, by extension, the Search API is not meant to be an exhaustive source of Tweets.
#
# Not all Tweets will be indexed or made available via the search interface.
#
# Twitter’s standard search API only “searches against a sampling of recent Tweets published in the past 7 days.”
#
# https://docs.tweepy.org/en/stable/api.html#tweepy.API.search_tweets

# %%
# define pretty print function
def pretty_print_json(input):
    print(json.dumps(input, indent=4))

# %%
# Use api basic search to get 2 tweets given the query 
search_results = api.search_tweets("new york", lang="en", count=1)
print(type(search_results))
print(search_results)
# Out:
# <class 'tweepy.models.SearchResults'>
# [Status(_api=<tweepy.api.API object at 0x7f944fbe3b20>, _json={'created_at': 'Thu Sep 08 18:43:59 +0000 2022', 'id': 1567946870147653634, 'id_str': '1567946870147653634', 'text': 'I am selling my Harry Styles tickets for New York, NY Sep 10  can’t make it to the show HMU if interested 🙏', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 298025041, 'id_str': '298025041', 'name': 'David', 'screen_name': 'david23d2', 'location': '', 'description': 'No time is wasted', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 2, 'friends_count': 0, 'listed_count': 0, 'created_at': 'Fri May 13 14:46:19 +0000 2011', 'favourites_count': 0, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 4, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1558889263323824134/1Zl80K9f_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1558889263323824134/1Zl80K9f_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/298025041/1660503154', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2022, 9, 8, 18, 43, 59, tzinfo=datetime.timezone.utc), id=1567946870147653634, id_str='1567946870147653634', text='I am selling my Harry Styles tickets for New York, NY Sep 10  can’t make it to the show HMU if interested 🙏', truncated=False, entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, metadata={'iso_language_code': 'en', 'result_type': 'recent'}, source='Twitter for iPhone', source_url='http://twitter.com/download/iphone', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x7f944fbe3b20>, _json={'id': 298025041, 'id_str': '298025041', 'name': 'David', 'screen_name': 'david23d2', 'location': '', 'description': 'No time is wasted', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 2, 'friends_count': 0, 'listed_count': 0, 'created_at': 'Fri May 13 14:46:19 +0000 2011', 'favourites_count': 0, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 4, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1558889263323824134/1Zl80K9f_normal.jpg', 'pr ...

# %%
print("--------------First tweet meta JSON data-------------")
pretty_print_json(search_results[0]._json)
# Out:
# --------------First tweet meta JSON data-------------
# {
#     "created_at": "Thu Sep 08 18:43:59 +0000 2022",
#     "id": 1567946870147653634,
#     "id_str": "1567946870147653634",
#     "text": "I am selling my Harry Styles tickets for New York, NY Sep 10  can\u2019t make it to the show HMU if interested \ud83d\ude4f",
#     "truncated": false,
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "user_mentions": [],
#         "urls": []
#     },
#     "metadata": {
#         "iso_language_code": "en",
#         "result_type": "recent"
#     },
#     "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "in_reply_to_screen_name": null,
#     "user": {
#         "id": 298025041,
#         "id_str": "298025041",
#         "name": "David",
#         "screen_name": "david23d2",
#         "location": "",
#         "description": "No time is wasted",
#         "url": null,
#         "entities": {
#             "description": {
#                 "urls": []
#             }
#         },
#         "protected": false,
#         "followers_count": 2,
#         "friends_count": 0,
#         "listed_count": 0,
#         "created_at": "Fri May 13 14:46:19 +0000 2011",
#         "favourites_count": 0,
#         "utc_offset": null,
#         "time_zone": null,
#         "geo_enabled": false,
#         "verified": false,
#         "statuses_count": 4,
#         "lang": null,
#         "contributors_enabled": false,
#         "is_translator": false,
#         "is_translation_enabled": false,
#         "profile_background_color": "C0DEED",
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_tile": false,
#         "profile_image_url": "http://pbs.twimg.com/profile_images/1558889263323824134/1Zl80K9f_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/1558889263323824134/1Zl80K9f_normal.jpg",
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/298025041/1660503154",
#         "profile_link_color": "1DA1F2",
#         "profile_sidebar_border_color": "C0DEED",
#         "profile_sidebar_fill_color": "DDEEF6",
#         "profile_text_color": "333333",
#         "profile_use_background_image": true,
#         "has_extended_profile": false,
#         "default_profile": true,
#         "default_profile_image": false,
#         "following": false,
#         "follow_request_sent": false,
#         "notifications": false,
#         "translator_type": "none",
#         "withheld_in_countries": []
#     },
#     "geo": null,
#     "coordinates": null,
#     "place": null,
#     "contributors": null,
#     "is_quote_status": false,
#     "retweet_count": 0,
#     "favorite_count": 0,
#     "favorited": false,
#     "retweeted": false,
#     "lang": "en"
# }

# %% [markdown]
# ### Search multiple tweets

# %%
number_of_tweets=100
search_results = api.search_tweets("texas OR maryland", lang="en", count=number_of_tweets)

for i in range(0,number_of_tweets):
    try:
        print("-------- tweet = ",i," -------")
        print("text = ",search_results[i]._json["text"])
        print("retweeted = ",search_results[i]._json["retweeted"])
        print("retweet_count = ",search_results[i]._json["retweet_count"])
        print("created_at =" ,search_results[i]._json["created_at"])
        print("id_str = ",search_results[i]._json["id_str"])
        print("url = https://twitter.com/i/web/status/"+search_results[i]._json["id_str"])

    except:
        print("ERROR")
# Out:
# -------- tweet =  0  -------
# text =  RT @TonyHussein4: Texas Paul is done with the Trump rally MAGA Republican bullshit. Watch the video to understand why #TrumpIsANationalSecu…
# retweeted =  False
# retweet_count =  98
# created_at = Thu Sep 08 18:44:00 +0000 2022
# id_str =  1567946873494970369
# url = https://twitter.com/i/web/status/1567946873494970369
# -------- tweet =  1  -------
# text =  ObamaCare is the greatest threat in Texas to Republicans. Bernie claims FAKE "global warming" is worse.
# retweeted =  False
# retweet_count =  0
# created_at = Thu Sep 08 18:43:59 +0000 2022
# id_str =  1567946872014393344
# url = https://twitter.com/i/web/status/1567946872014393344
# -------- tweet =  2  -------
# text =  RT @DanRather: There was an unusual weather event in California and Governor Newsom asked residents to pitch in during a moment of crisis.…
# retweeted =  False
# retweet_count =  12238
# created_at = Thu Sep 08 18:43:59 +0000 2022
# id_str =  1567946870135078918
# url = https://twitter.com/i/web/status/1567946870135078918
# -------- tweet =  3  -------
# text =  Topology Texas Nicknames Border Greatest Puerto
# ؟?
# نمشے
#
# 🔹VOX2🔹
# 🔹VOX2🔹
# 🔹VOX2🔹
# retweeted =  False
# retweet_count =  0
# created_at = Thu Sep 08 18:43:59 +0000 2022
# id_str =  1567946869296201729
# url = https://twitter.com/i/web/status/1567946869296201729
# -------- tweet =  4  -------
# text =  @justinamash I support Biden and I'll be the first to tell him he is wrong about Section 239, just like the right i… https://t.co/HP8B3lmpFZ
# retweeted =  False
# retweet_count =  0
# created_at = Thu Sep 08 18:43:58 +0000 2022
# id_str =  1567946867320967174
# url = https://twitter.com/i/web/status/1567946867320967174
# -------- tweet =  5  -------
# text =  RT @BrittanyinTexas: Beto is on the cusp of turning Texas Blue for America one city at a time!
# retweeted =  False
# retweet_count =  646
# created_at = Thu Sep 08 18:43:58 +0000 2022
# id_str =  1567946865580339201
# url = https://twitter.com/i/web/status/1567946865580339201
# -------- tweet =  6  -------
# text =  RT @BMeiselas: The way Gavin Newsom is handling the heat wave in California is exactly how an actual leader is supposed to handle a crisis.…
# retweeted =  False
# retweet_count =  1695
# created_at = Thu Sep 08 18:43:58 +0000 2022
# id_str =  1567946863701295104
# url = https://twitter.com/i/web/status/1567946863701295104
# -------- tweet =  7  -------
# text =  @pinkyafterdark thank u boo! i need to come to texas so we can trap out together fr 😭
# retweeted =  False
# retweet_count =  0
# created_at = Thu Sep 08 18:43:57 +0000 2022
# id_str =  1567946863042600960
# url = https://twitter.com/i/web/status/1567946863042600960
# -------- tweet =  8  -------
# text =  RT @BrittanyinTexas: Beto is on the cusp of turning Texas Blue for America one city at a time!
# retweeted =  False
# retweet_count =  646
# created_at = Thu Sep 08 18:43:57 +0000 2022
# id_str =  1567946862237487106
# url = https://twitter.com/i/web/status/1567946862237487106
# -------- tweet =  9  -------
# text =  RT @jerrybrito: I’m glad to see folks taking to court the arguments re Tornado Cash that Coin Center has been developing. The complaint fil…
# retweeted =  False
# retweet_count =  17
# created_at = Thu Sep 08 18:43:57 +0000 2022
# id_str =  1567946862082097154
# url = https://twitter.com/i/web/status/1567946862082097154
# -------- tweet =  10  -------
# text =  RT @BenjaminGolan: The last time the UK had a king, Texas Tech (led by a 1st year coach) went undefeated in conference play and won the con…
# retweeted =  False
# retweet_count =  19
# created_at = Thu Sep 08 18:43:56 +0000 2022
# id_str =  1567946858814738434
# url = https://twitter.com/i/web/status/1567946858814738434
# -------- tweet =  11  -------
# text =  RT @greg_price11: DC city council member:
#
# “The governors of Texas and Arizona have created this crisis [and] have  turned us into a border…
# retweeted =  False
# retweet_count =  880
# created_at = Thu Sep 08 18:43:56 +0000 2022
# id_str =  1567946857992822786
# url = https://twitter.com/i/web/status/1567946857992822786
# -------- tweet =  12  -------
# text =  RT @BrittanyinTexas: Beto is on the cusp of turning Texas Blue for America one city at a time!
# retweeted =  False
# retweet_count =  646
# created_at = Thu Sep 08 18:43:56 +0000 2022
# id_str =  1567946857304805377
# url = https://twitter.com/i/web/status/1567946857304805377
# -------- tweet =  13  -------
# text =  RT @juliejohnsonTX: Many people still say they don’t vote because they don’t know how.
#
# It’s time to put those excuses behind us and use o…
# retweeted =  False
# retweet_count =  47
# created_at = Thu Sep 08 18:43:56 +0000 2022
# id_str =  1567946856939900934
# url = https://twitter.com/i/web/status/1567946856939900934
# -------- tweet =  14  -------
# text =  RT @MarissaKawehi: And I know my queer and trans friends feel the same way when legislation is passed that restricts their access to health…
# retweeted =  False
# retweet_count =  1
# created_at = Thu Sep 08 18:43:55 +0000 2022
# id_str =  1567946855115276289
# url = https://twitter.com/i/web/status/1567946855115276289
# -------- tweet =  15  -------
# text =  RT @BrittanyinTexas: Beto is on the cusp of turning Texas Blue for America one city at a time!
# retweeted =  False
# retweet_count =  646
# created_at = Thu Sep 08 18:43:55 +0000 2022
# id_str =  1567946854943408132
# url = https://twitter.com/i/web/status/1567946854943408132
# -------- tweet =  16  -------
# text =  RT @CraigHuey: Crazy how Arizona and Texas are hotter than California but they have electricity.
# retweeted =  False
# retweet_count =  2293
# created_at = Thu Sep 08 18:43:55 +0000 2022
# id_str =  1567946854104535041
# url = https://twitter.com/i/web/status/1567946854104535041
# -------- tweet =  17  -------
# text =  RT @Madandshaggy: @GregAbbott_TX Back in 5/21/91 #QueenElizabeth got a big Texas welcome.
# https://t.co/6LN1SIzRxd https://t.co/72qRdyBZ29
# retweeted =  False
# retweet_count =  1
# created_at = Thu Sep 08 18:43:55 +0000 2022
# id_str =  1567946853735596032
# url = https://twitter.com/i/web/status/1567946853735596032
# -------- tweet =  18  -------
# text =  RT @CollierForTexas: “I could not be more proud to be endorsed by Sen. Kel Seliger who has represented and fought for the people of the Pan…
# retweeted =  False
# retweet_count =  5
# created_at = Thu Sep 08 18:43:55 +0000 2022
# id_str =  1567946853580439552
# url = https://twitter.com/i/web/status/1567946853580439552
# -------- tweet =  19  -------
# text =  @DanRather Texas had issues because they went to windmills and they froze. If they had stayed with fossil fuels tho… https://t.co/rUo8EQBi9J
# retweeted =  False
# retweet_count =  0
# created_at = Thu Sep 08 18:43:55 +0000 2022
# id_str =  1567946851361464322
# url = https://twitter.com/i/web/status/1567946851361464322
# -------- tweet =  20  -------
# text =  RT @weather_history: September 8, 1900:
#
# One of the US' worst hurricanes made landfall in Texas near Galveston. Much of the city was comple…
# retweeted =  False
# retweet_count =  16
# created_at = Thu Sep 08 18:43:53 +0000 2022
# id_str =  1567946846294638598
# url = https://twitter.com/i/web/status/1567946846294638598
# -------- tweet =  21  -------
# text =  @SearchBuzz We don’t allow those kind in our fine state but we’ll come visit you in Texas
# retweeted =  False
# retweet_count =  0
# created_at = Thu Sep 08 18:43:53 +0000 2022
# id_str =  1567946846181416962
# url = https://twitter.com/i/web/status/1567946846181416962
# -------- tweet =  22  -------
# text =  Texas is so country. We just got out the car and it smell like straight horse shit😑
# retweeted =  False
# retweet_count =  0
# created_at = Thu Sep 08 18:43:53 +0000 2022
# id_str =  1567946844013035525
# url = https://twitter.com/i/web/status/1567946844013035525
# -------- tweet =  23  -------
# text =  RT @IBJIYONGI: The news about the PrEP ruling in Texas has completely wrecked me and I want everyone to read this thread to understand why…
# retweeted =  False
# retweet_count =  510
# created_at = Thu Sep 08 18:43:52 +0000 2022
# id_str =  1567946840997302278
# url = https://twitter.com/i/web/status/1567946840997302278
# -------- tweet =  24  -------
# text =  RT @TheFieldOf12: Tonight on AFTER DARK: Week Two Preview &amp; Picks!
#
# Join @gwizzy12, @ClintStoerner, and @chackenberg1 at 10pm ET to preview…
# retweeted =  False
# retweet_count =  2
# created_at = Thu Sep 08 18:43:51 +0000 2022
# id_str =  1567946838140936193
# url = https://twitter.com/i/web/status/1567946838140936193
# -------- tweet =  25  -------
# text =  RT @Plz_Relax_: Water crises in Flint, Jackson, Hawaii, and Baltimore... rolling blackouts in Puerto Rico... massive flooding from Pakistan…
# retweeted =  False
# retweet_count =  1914
# created_at = Thu Sep 08 18:43:51 +0000 2022
# id_str =  1567946836568342529
# url = https://twitter.com/i/web/status/1567946836568342529
# -------- tweet =  26  -------
# text =  @SkurpySocial I recreated the Mona Lisa but with some San Antonio, Texas sprinkled on top.
#
# 🤘🤘 https://t.co/pjTOkkTxht
# retweeted =  False
# retweet_count =  0
# created_at = Thu Sep 08 18:43:51 +0000 2022
# id_str =  1567946835175645187
# url = https://twitter.com/i/web/status/1567946835175645187
# -------- tweet =  27  -------
# text =  RT @Not_the_Bee: Mayor Muriel Bowser announces "public emergency" in DC because Texas and Arizona keep sending busloads of illegal aliens t…
# retweeted =  False
# retweet_count =  45
# created_at = Thu Sep 08 18:43:51 +0000 2022
# id_str =  1567946834890334211
# url = https://twitter.com/i/web/status/1567946834890334211
# -------- tweet =  28  -------
# text =  RT @ABC: Texas has spent over $12 million as of mid-August in busing migrants to New York City, Washington, D.C., and Chicago, a spokespers…
# retweeted =  False
# retweet_count =  90
# created_at = Thu Sep 08 18:43:49 +0000 2022
# id_str =  1567946830029418496
# url = https://twitter.com/i/web/status/1567946830029418496
# -------- tweet =  29  -------
# text =  Puppy Died After Being Left In Metal Cage In Extreme Texas Heat https://t.co/4z8hbvxpZT
# retweeted =  False
# retweet_count =  0
# created_at = Thu Sep 08 18:43:48 +0000 2022
# id_str =  1567946824631341059
# url = https://twitter.com/i/web/status/1567946824631341059
# -------- tweet =  30  -------
# text =  Donors run Texas confirmed. 🤣 https://t.co/pQkBlHEsOd
# retweeted =  False
# retweet_count =  0
# created_at = Thu Sep 08 18:43:48 +0000 2022
# id_str =  1567946824454914054
# url = https://twitter.com/i/web/status/1567946824454914054
# -------- tweet =  31  -------
# text =  RT @deplorablican: Maybe Texas should send a couple busses of illegals to Joey's next "rally".  He will finally have an audience.
# retweeted =  False
# retweet_count =  11
# created_at = Thu Sep 08 18:43:48 +0000 2022
# id_str =  1567946822932647938
# url = https://twitter.com/i/web/status/1567946822932647938
# -------- tweet =  32  -------
# text =  @ACTBrigitte Cool. Now explain why Texas can't handle heat or cold snaps.
# retweeted =  False
# retweet_count =  0
# created_at = Thu Sep 08 18:43:47 +0000 2022
# id_str =  1567946819619160064
# url = https://twitter.com/i/web/status/1567946819619160064
# -------- tweet =  33  -------
# text =  RT @democracynow: A federal judge in Texas has ruled in favor of a group of Christians who sued to overturn a federal requirement that empl…
# retweeted =  False
# retweet_count =  3
# created_at = Thu Sep 08 18:43:47 +0000 2022
# id_str =  1567946819023572997
# url = https://twitter.com/i/web/status/1567946819023572997
# -------- tweet =  34  -------
# text =  I wish there was a "go fund me" link to send all the illegals to sanctuary cities. I'd certainly donate. Fck you Bo… https://t.co/BSCbp6iLin
# retweeted =  False
# retweet_count =  0
# created_at = Thu Sep 08 18:43:47 +0000 2022
# id_str =  1567946818365038593
# url = https://twitter.com/i/web/status/1567946818365038593
# -------- tweet =  35  -------
# text =  RT @ColinAllredTX: A Texas where everyone has the chance to chase their version of the American dream is within our grasp, but we have to f…
# retweeted =  False
# retweet_count =  9
# created_at = Thu Sep 08 18:43:47 +0000 2022
# id_str =  1567946817685291014
# url = https://twitter.com/i/web/status/1567946817685291014
# -------- tweet =  36  -------
# text =  @andrewneeme @JPReilly15 @BartHanson @CommerceCasino Guessing Texas game is match the stack where beyond 40 is achi… https://t.co/0VHaNZ2cJX
# retweeted =  False
# retweet_count =  0
# created_at = Thu Sep 08 18:43:46 +0000 2022
# id_str =  1567946814396956673
# url = https://twitter.com/i/web/status/1567946814396956673
# -------- tweet =  37  -------
# text =  @newsmax 10 days? Good thing it’s the UK because in Texas we would have to crank down the freezer!
# retweeted =  False
# retweet_count =  0
# created_at = Thu Sep 08 18:43:46 +0000 2022
# id_str =  1567946813986017283
# url = https://twitter.com/i/web/status/1567946813986017283
# -------- tweet =  38  -------
# text =  RT @barstoolUMD: Queen Elizabeth II attended a Maryland v. UNC football game on Oct. 19, 1957, where the Terps upset a #14 ranked UNC in Co…
# retweeted =  False
# retweet_count =  39
# created_at = Thu Sep 08 18:43:45 +0000 2022
# id_str =  1567946812086194176
# url = https://twitter.com/i/web/status/1567946812086194176
# -------- tweet =  39  -------
# text =  just realized im not gonna be in texas while bp r here and my brother is pissed bc he wanted me to go with him 😬
# retweeted =  False
# retweet_count =  0
# created_at = Thu Sep 08 18:43:44 +0000 2022
# id_str =  1567946805144424448
# url = https://twitter.com/i/web/status/1567946805144424448
# -------- tweet =  40  -------
# text =  RT @TimothyJFanning: Six minutes in the Alamo, 12 minutes on the river and a glimpse at the heritage of Texas were the highlights as Queen…
# retweeted =  False
# retweet_count =  3
# created_at = Thu Sep 08 18:43:43 +0000 2022
# id_str =  1567946804565626883
# url = https://twitter.com/i/web/status/1567946804565626883
# -------- tweet =  41  -------
# text =  @DGIveyNASCARFan @laura24fan @kross700 @ToddTPrice24 @MarcelloVanic @JLee418 @jonesbrent570 @43324FAN Huge upgrade from Texas
# retweeted =  False
# retweet_count =  0
# created_at = Thu Sep 08 18:43:43 +0000 2022
# id_str =  1567946804376879106
# url = https://twitter.com/i/web/status/1567946804376879106
# -------- tweet =  42  -------
# text =  RT @RochelleMGarza: Honored to have the endorsement of the @OrganizeTexas. Together we are going to organize and build a Texas we can be pr…
# retweeted =  False
# retweet_count =  36
# created_at = Thu Sep 08 18:43:43 +0000 2022
# id_str =  1567946804372594688
# url = https://twitter.com/i/web/status/1567946804372594688
# -------- tweet =  43  -------
# text =  whitelist Interworking @whodby @deara9626 @adonis_temple @bat_texas @Zodian_IX @Skyroket1128 @Bridget32098397… https://t.co/sOR1bsIJvH
# retweeted =  False
# retweet_count =  0
# created_at = Thu Sep 08 18:43:43 +0000 2022
# id_str =  1567946803831783425
# url = https://twitter.com/i/web/status/1567946803831783425
# -------- tweet =  44  -------
# text =  RT @tatefrazier: The time Queen Elizabeth II watched Maryland play UNC in football over 60 years ago, shoutout @awaytoworthy for the note h…
# retweeted =  False
# retweet_count =  54
# created_at = Thu Sep 08 18:43:43 +0000 2022
# id_str =  1567946801201782784
# url = https://twitter.com/i/web/status/1567946801201782784
# -------- tweet =  45  -------
# text =  RT @NathanMackBrown: I was born in San Antonio, Texas, but moved away after college to find a saner place to live. My dad, sister &amp; 2 nephe…
# retweeted =  False
# retweet_count =  630
# created_at = Thu Sep 08 18:43:42 +0000 2022
# id_str =  1567946799016706048
# url = https://twitter.com/i/web/status/1567946799016706048
# -------- tweet =  46  -------
# text =  RT @TheFieldOf12: Tonight on AFTER DARK: Week Two Preview &amp; Picks!
#
# Join @gwizzy12, @ClintStoerner, and @chackenberg1 at 10pm ET to preview…
# retweeted =  False
# retweet_count =  2
# created_at = Thu Sep 08 18:43:42 +0000 2022
# id_str =  1567946798928633856
# url = https://twitter.com/i/web/status/1567946798928633856
# -------- tweet =  47  -------
# text =  RT @DanRather: There was an unusual weather event in California and Governor Newsom asked residents to pitch in during a moment of crisis.…
# retweeted =  False
# retweet_count =  12238
# created_at = Thu Sep 08 18:43:42 +0000 2022
# id_str =  1567946796948668418
# url = https://twitter.com/i/web/status/1567946796948668418
# -------- tweet =  48  -------
# text =  RT @BillFOXLA: A ridiculous statement.
#
# Washington D.C., a metro of 700,000 people, has had about 8,000 migrants dropped off by the state o…
# retweeted =  False
# retweet_count =  825
# created_at = Thu Sep 08 18:43:41 +0000 2022
# id_str =  1567946795145207815
# url = https://twitter.com/i/web/status/1567946795145207815
# -------- tweet =  49  -------
# text =  RT @PatsyeStevenson: Do I know anyone who could help someone struggling with domestic violence in Texas at all?
# retweeted =  False
# retweet_count =  14
# created_at = Thu Sep 08 18:43:41 +0000 2022
# id_str =  1567946794264571904
# url = https://twitter.com/i/web/status/1567946794264571904
# -------- tweet =  50  -------
# text =  RT @democracynow: A federal judge in Texas has ruled in favor of a group of Christians who sued to overturn a federal requirement that empl…
# retweeted =  False
# retweet_count =  3
# created_at = Thu Sep 08 18:43:41 +0000 2022
# id_str =  1567946793916469248
# url = https://twitter.com/i/web/status/1567946793916469248
# -------- tweet =  51  -------
# text =  RT @texascyber: Join the 5th annual🤠@TexasCyber @TexasCyberConf
# in 13 days in Austin, Tx. Sept.22-24 Hyatt Regency over 125 Speakers, Amazi…
# retweeted =  False
# retweet_count =  3
# created_at = Thu Sep 08 18:43:41 +0000 2022
# id_str =  1567946793778057217
# url = https://twitter.com/i/web/status/1567946793778057217
# -------- tweet =  52  -------
# text =  RT @CFBRanking: Which will be higher?
#
# Texas’ best ever combined GPA or their yards per carry against Alabama on Saturday? https://t.co/RYR…
# retweeted =  False
# retweet_count =  1
# created_at = Thu Sep 08 18:43:41 +0000 2022
# id_str =  1567946793630973954
# url = https://twitter.com/i/web/status/1567946793630973954
# -------- tweet =  53  -------
# text =  RT @IndyCaronNBC: Few dared to take the high line at Texas earlier this year... until @JosefNewgarden on the final lap.
#
# His pass on teamma…
# retweeted =  False
# retweet_count =  6
# created_at = Thu Sep 08 18:43:41 +0000 2022
# id_str =  1567946793530294275
# url = https://twitter.com/i/web/status/1567946793530294275
# -------- tweet =  54  -------
# text =  RT @jwharris: More than 3,300 Texans were members of the Oath Keepers
#
# - Texas had more members of the far-right extremist group than any…
# retweeted =  False
# retweet_count =  151
# created_at = Thu Sep 08 18:43:41 +0000 2022
# id_str =  1567946793136304128
# url = https://twitter.com/i/web/status/1567946793136304128
# -------- tweet =  55  -------
# text =  RT @MuellerSheWrote: NEW RULE: People who don’t believe in climate change shouldn’t be allowed to comment on rolling blackouts in CA, espec…
# retweeted =  False
# retweet_count =  2647
# created_at = Thu Sep 08 18:43:41 +0000 2022
# id_str =  1567946792955949056
# url = https://twitter.com/i/web/status/1567946792955949056
# -------- tweet =  56  -------
# text =  @GregAbbott_TX Back in 5/21/91 #QueenElizabeth got a big Texas welcome.
# https://t.co/6LN1SIzRxd https://t.co/72qRdyBZ29
# retweeted =  False
# retweet_count =  1
# created_at = Thu Sep 08 18:43:40 +0000 2022
# id_str =  1567946792272265216
# url = https://twitter.com/i/web/status/1567946792272265216
# -------- tweet =  57  -------
# text =  RT @CollierForTexas: “I could not be more proud to be endorsed by Sen. Kel Seliger who has represented and fought for the people of the Pan…
# retweeted =  False
# retweet_count =  4
# created_at = Thu Sep 08 18:43:40 +0000 2022
# id_str =  1567946789608734721
# url = https://twitter.com/i/web/status/1567946789608734721
# -------- tweet =  58  -------
# text =  RT @HoustonChron: “In the past, Kristina’s situation would have been dealt with much earlier in pregnancy,” the doctor said. "What we're go…
# retweeted =  False
# retweet_count =  553
# created_at = Thu Sep 08 18:43:39 +0000 2022
# id_str =  1567946787713064961
# url = https://twitter.com/i/web/status/1567946787713064961
# -------- tweet =  59  -------
# text =  RT @RAICESTEXAS: $14 million could go a long way to fixing the energy grid, or providing healthcare to Texans, or universal early childhood…
# retweeted =  False
# retweet_count =  12
# created_at = Thu Sep 08 18:43:39 +0000 2022
# id_str =  1567946787549331458
# url = https://twitter.com/i/web/status/1567946787549331458
# -------- tweet =  60  -------
# text =  RT @Iamlestacks: Just listed in rockwall Texas. 4 bed, 4 bath, 4,000sq.ft fully remodeled with a pool in a gated community.
#
# I show more n…
# retweeted =  False
# retweet_count =  5
# created_at = Thu Sep 08 18:43:39 +0000 2022
# id_str =  1567946785993232385
# url = https://twitter.com/i/web/status/1567946785993232385
# -------- tweet =  61  -------
# text =  RT @CollierForTexas: “I could not be more proud to be endorsed by Sen. Kel Seliger who has represented and fought for the people of the Pan…
# retweeted =  False
# retweet_count =  4
# created_at = Thu Sep 08 18:43:39 +0000 2022
# id_str =  1567946784504270850
# url = https://twitter.com/i/web/status/1567946784504270850
# -------- tweet =  62  -------
# text =  @yrsdulce Mf she ain’t nun to do with us in Texas you can’t even go to England
# retweeted =  False
# retweet_count =  0
# created_at = Thu Sep 08 18:43:38 +0000 2022
# id_str =  1567946783413907457
# url = https://twitter.com/i/web/status/1567946783413907457
# -------- tweet =  63  -------
# text =  RT @dallasnews: Photos: Queen Elizabeth once delighted Dallas on a trip to Texas https://t.co/WyltSx1kER
# retweeted =  False
# retweet_count =  5
# created_at = Thu Sep 08 18:43:38 +0000 2022
# id_str =  1567946782625202177
# url = https://twitter.com/i/web/status/1567946782625202177
# -------- tweet =  64  -------
# text =  RT @BMeiselas: The way Gavin Newsom is handling the heat wave in California is exactly how an actual leader is supposed to handle a crisis.…
# retweeted =  False
# retweet_count =  1695
# created_at = Thu Sep 08 18:43:38 +0000 2022
# id_str =  1567946781849264131
# url = https://twitter.com/i/web/status/1567946781849264131
# -------- tweet =  65  -------
# text =  RT @JonesHospodTX: Texas also had the most people who were either elected officials, law enforcement officers, military members or first re…
# retweeted =  False
# retweet_count =  25
# created_at = Thu Sep 08 18:43:37 +0000 2022
# id_str =  1567946776069521409
# url = https://twitter.com/i/web/status/1567946776069521409
# -------- tweet =  66  -------
# text =  RT @RAICESTEXAS: $14 million could go a long way to fixing the energy grid, or providing healthcare to Texans, or universal early childhood…
# retweeted =  False
# retweet_count =  12
# created_at = Thu Sep 08 18:43:36 +0000 2022
# id_str =  1567946775461502977
# url = https://twitter.com/i/web/status/1567946775461502977
# -------- tweet =  67  -------
# text =  RT @BenjaminGolan: The last time the UK had a king, Texas Tech (led by a 1st year coach) went undefeated in conference play and won the con…
# retweeted =  False
# retweet_count =  19
# created_at = Thu Sep 08 18:43:35 +0000 2022
# id_str =  1567946770776489985
# url = https://twitter.com/i/web/status/1567946770776489985
# -------- tweet =  68  -------
# text =  @2ndmrschappers I have reported and blocked her, she is an associate professor at Carnegiee Mellon University in Te… https://t.co/g10gsXSroQ
# retweeted =  False
# retweet_count =  0
# created_at = Thu Sep 08 18:43:35 +0000 2022
# id_str =  1567946770671632384
# url = https://twitter.com/i/web/status/1567946770671632384
# -------- tweet =  69  -------
# text =  RT @juliejohnsonTX: Many people still say they don’t vote because they don’t know how.
#
# It’s time to put those excuses behind us and use o…
# retweeted =  False
# retweet_count =  47
# created_at = Thu Sep 08 18:43:34 +0000 2022
# id_str =  1567946764619071490
# url = https://twitter.com/i/web/status/1567946764619071490
# -------- tweet =  70  -------
# text =  RT @RAICESTEXAS: $14 million could go a long way to fixing the energy grid, or providing healthcare to Texans, or universal early childhood…
# retweeted =  False
# retweet_count =  12
# created_at = Thu Sep 08 18:43:34 +0000 2022
# id_str =  1567946763666866177
# url = https://twitter.com/i/web/status/1567946763666866177
# -------- tweet =  71  -------
# text =  @john_linnus @ZenithOfChaos @USAveteranArmy @elonmusk They’re not on the property either. Only the Texas factory wh… https://t.co/smDFWxYBUw
# retweeted =  False
# retweet_count =  0
# created_at = Thu Sep 08 18:43:33 +0000 2022
# id_str =  1567946760827600897
# url = https://twitter.com/i/web/status/1567946760827600897
# -------- tweet =  72  -------
# text =  @jaichele70 @doulonkyriou @FFDecker @NCM_VintaPixel @POTUS No. The woman in Texas who is being forced to give birth… https://t.co/fszO6yDBaQ
# retweeted =  False
# retweet_count =  0
# created_at = Thu Sep 08 18:43:32 +0000 2022
# id_str =  1567946755219591170
# url = https://twitter.com/i/web/status/1567946755219591170
# -------- tweet =  73  -------
# text =  @AlabamaFTBL @emmanuelhende17 @malachi_moore13 @Prince_Tay_ Howdy Alabama Football 🏈. Please make Dog Food out of “… https://t.co/RU4drM22Fr
# retweeted =  False
# retweet_count =  0
# created_at = Thu Sep 08 18:43:30 +0000 2022
# id_str =  1567946747837820928
# url = https://twitter.com/i/web/status/1567946747837820928
# -------- tweet =  74  -------
# text =  RT @RAICESTEXAS: $14 million could go a long way to fixing the energy grid, or providing healthcare to Texans, or universal early childhood…
# retweeted =  False
# retweet_count =  12
# created_at = Thu Sep 08 18:43:29 +0000 2022
# id_str =  1567946742598930434
# url = https://twitter.com/i/web/status/1567946742598930434
# -------- tweet =  75  -------
# text =  RT @Katie_Statesman: Texas  had the most elected officials, law enforcement officers, military members and first responders listed as membe…
# retweeted =  False
# retweet_count =  6
# created_at = Thu Sep 08 18:43:28 +0000 2022
# id_str =  1567946741474787328
# url = https://twitter.com/i/web/status/1567946741474787328
# -------- tweet =  76  -------
# https://t.co/pcitSVpvNk https://t.co/UKy3w2a3Feng TONIGHT!  Check it out! 🗳🌊🇺🇸
# retweeted =  False
# retweet_count =  8
# created_at = Thu Sep 08 18:43:28 +0000 2022
# id_str =  1567946740892049412
# url = https://twitter.com/i/web/status/1567946740892049412
# -------- tweet =  77  -------
# text =  RT @Im_Alex_Morgan: @ChinaWestWatch1 At first, I breathed a sigh of relief that I no longer live in the bass-ackwards state of Texas. But t…
# retweeted =  False
# retweet_count =  2
# created_at = Thu Sep 08 18:43:28 +0000 2022
# id_str =  1567946739813842946
# url = https://twitter.com/i/web/status/1567946739813842946
# -------- tweet =  78  -------
# text =  Article first Texas Wealth Socialization Plate
# retweeted =  False
# retweet_count =  0
# created_at = Thu Sep 08 18:43:28 +0000 2022
# id_str =  1567946738719236096
# url = https://twitter.com/i/web/status/1567946738719236096
# -------- tweet =  79  -------
# text =  RT @MeekPhill_: Sources: Alabama and Texas will proceed as scheduled this Saturday despite Queen Elizabeth II’s sudden passing this afterno…
# retweeted =  False
# retweet_count =  2
# created_at = Thu Sep 08 18:43:27 +0000 2022
# id_str =  1567946737750364163
# url = https://twitter.com/i/web/status/1567946737750364163
# -------- tweet =  80  -------
# text =  @1nn0v8IT @zoechen717 @gr8__awakening @ChuckCallesto You might be correct, direct from the Texas governor it’s 6,50… https://t.co/dzJkFUXqo3
# retweeted =  False
# retweet_count =  0
# created_at = Thu Sep 08 18:43:27 +0000 2022
# id_str =  1567946737460908032
# url = https://twitter.com/i/web/status/1567946737460908032
# -------- tweet =  81  -------
# text =  Why I like governed Newsom he asked citizens to cut back and keep power on Texas abbot did nothing in extreme cold… https://t.co/SQuP2aWj3z
# retweeted =  False
# retweet_count =  0
# created_at = Thu Sep 08 18:43:26 +0000 2022
# id_str =  1567946733245845504
# url = https://twitter.com/i/web/status/1567946733245845504
# -------- tweet =  82  -------
# text =  RT @CollierForTexas: “I could not be more proud to be endorsed by Sen. Kel Seliger who has represented and fought for the people of the Pan…
# retweeted =  False
# retweet_count =  5
# created_at = Thu Sep 08 18:43:26 +0000 2022
# id_str =  1567946732335673346
# url = https://twitter.com/i/web/status/1567946732335673346
# -------- tweet =  83  -------
# text =  RT @BillFOXLA: A ridiculous statement.
#
# Washington D.C., a metro of 700,000 people, has had about 8,000 migrants dropped off by the state o…
# retweeted =  False
# retweet_count =  826
# created_at = Thu Sep 08 18:43:26 +0000 2022
# id_str =  1567946730326446085
# url = https://twitter.com/i/web/status/1567946730326446085
# -------- tweet =  84  -------
# text =  RT @FoxNews: Border officers in Texas seize nearly $12 million in methamphetamine from tractor trailer https://t.co/HhoPboJGIN
# retweeted =  False
# retweet_count =  273
# created_at = Thu Sep 08 18:43:25 +0000 2022
# id_str =  1567946729110003718
# url = https://twitter.com/i/web/status/1567946729110003718
# -------- tweet =  85  -------
# text =  RT @harrysmyoxygenx: 🆘URGENT NEURO MEDICAL🚨#HELP DOG HIT BY OWNER 🚑⚠️TO BE KILLED NOW⏰‼️
# 📍San Antonio ACS
#
# ❤️ TORONTO ❤️ #A644437
# ✨1yo m,…
# retweeted =  False
# retweet_count =  23
# created_at = Thu Sep 08 18:43:25 +0000 2022
# id_str =  1567946727692587009
# url = https://twitter.com/i/web/status/1567946727692587009
# -------- tweet =  86  -------
# text =  RT @TylerRichMusic: BOOM! NEW DATES! 🚨 Y’all told me over and over you wanted “Texas” “Midwest” “Florida” etc so join myself, @kyliemorgan,…
# retweeted =  False
# retweet_count =  8
# created_at = Thu Sep 08 18:43:25 +0000 2022
# id_str =  1567946726157463554
# url = https://twitter.com/i/web/status/1567946726157463554
# -------- tweet =  87  -------
# text =  Tonight on AFTER DARK: Week Two Preview &amp; Picks!
#
# Join @gwizzy12, @ClintStoerner, and @chackenberg1 at 10pm ET to p… https://t.co/z6Hhab7eUp
# retweeted =  False
# retweet_count =  2
# created_at = Thu Sep 08 18:43:25 +0000 2022
# id_str =  1567946726044225536
# url = https://twitter.com/i/web/status/1567946726044225536
# -------- tweet =  88  -------
# text =  RT @DanRather: There was an unusual weather event in California and Governor Newsom asked residents to pitch in during a moment of crisis.…
# retweeted =  False
# retweet_count =  12238
# created_at = Thu Sep 08 18:43:25 +0000 2022
# id_str =  1567946725695918080
# url = https://twitter.com/i/web/status/1567946725695918080
# -------- tweet =  89  -------
# text =  RT @TonyHussein4: Rafael Ted Cruz flew off to Cancun when his state, Texas, struggled with a killer winter storm, and major power cuts.
#
# Cr…
# retweeted =  False
# retweet_count =  153
# created_at = Thu Sep 08 18:43:24 +0000 2022
# id_str =  1567946725133795328
# url = https://twitter.com/i/web/status/1567946725133795328
# -------- tweet =  90  -------
# text =  RT @RAICESTEXAS: $14 million could go a long way to fixing the energy grid, or providing healthcare to Texans, or universal early childhood…
# retweeted =  False
# retweet_count =  12
# created_at = Thu Sep 08 18:43:24 +0000 2022
# id_str =  1567946723875504129
# url = https://twitter.com/i/web/status/1567946723875504129
# -------- tweet =  91  -------
# text =  RT @JulianGi11: I've spoken to a dozen OB-GYNs over the last several weeks who are afraid for the future. As long as the exemptions to the…
# retweeted =  False
# retweet_count =  263
# created_at = Thu Sep 08 18:43:24 +0000 2022
# id_str =  1567946722889945091
# url = https://twitter.com/i/web/status/1567946722889945091
# -------- tweet =  92  -------
# text =  RT @AlecBenjamin: TOUR STARTS TODAY . AUSTIN TEXAS . ! . https://t.co/Qv2M2K4GW2
# retweeted =  False
# retweet_count =  37
# created_at = Thu Sep 08 18:43:24 +0000 2022
# id_str =  1567946722248212482
# url = https://twitter.com/i/web/status/1567946722248212482
# -------- tweet =  93  -------
# text =  RT @murphsturph: Incredible footage: Queen Elizabeth II attends the University of North Carolina vs. the University of Maryland football ga…
# retweeted =  False
# retweet_count =  7
# created_at = Thu Sep 08 18:43:23 +0000 2022
# id_str =  1567946720595611648
# url = https://twitter.com/i/web/status/1567946720595611648
# -------- tweet =  94  -------
# text =  RT @EpochTimes: Wes Virdell, the #Texas State Director of @GunOwners of America, says the #SecondAmendment is the only thing keeping the Fe…
# retweeted =  False
# retweet_count =  36
# created_at = Thu Sep 08 18:43:23 +0000 2022
# id_str =  1567946720495169538
# url = https://twitter.com/i/web/status/1567946720495169538
# -------- tweet =  95  -------
# text =  RT @underdogdynasty: Houston survived UTSA in a 3OT thriller on Clayton Tune’s clutch 2-point conversion.
#
# After facing an early-season tes…
# retweeted =  False
# retweet_count =  1
# created_at = Thu Sep 08 18:43:23 +0000 2022
# id_str =  1567946720331599872
# url = https://twitter.com/i/web/status/1567946720331599872
# -------- tweet =  96  -------
# text =  RT @BillFOXLA: A ridiculous statement.
#
# Washington D.C., a metro of 700,000 people, has had about 8,000 migrants dropped off by the state o…
# retweeted =  False
# retweet_count =  826
# created_at = Thu Sep 08 18:43:22 +0000 2022
# id_str =  1567946716300574720
# url = https://twitter.com/i/web/status/1567946716300574720
# -------- tweet =  97  -------
# text =  @InkThePage @Texas_Made956 It's a false title, they are really fascists, and terrorists.  Try to pay attention.
# retweeted =  False
# retweet_count =  0
# created_at = Thu Sep 08 18:43:22 +0000 2022
# id_str =  1567946714392440833
# url = https://twitter.com/i/web/status/1567946714392440833
# -------- tweet =  98  -------
# text =  RT @BrittanyinTexas: Beto is on the cusp of turning Texas Blue for America one city at a time!
# retweeted =  False
# retweet_count =  646
# created_at = Thu Sep 08 18:43:22 +0000 2022
# id_str =  1567946712974508040
# url = https://twitter.com/i/web/status/1567946712974508040
# -------- tweet =  99  -------
# text =  RT @mommabae1: @SueMassa256 Check out the prisons in Texas, Georgia and Mississippi right now. It's a cottage industry.
# retweeted =  False
# retweet_count =  7
# created_at = Thu Sep 08 18:43:21 +0000 2022
# id_str =  1567946711703736320
# url = https://twitter.com/i/web/status/1567946711703736320

# %% [markdown]
# ### Cursor Tutorial
#
# Source: https://docs.tweepy.org/en/v3.5.0/cursor_tutorial.html
#
# Pagination, also known as paging, is the process of dividing a document into discrete pages, either electronic pages or printed pages.
#
# We use pagination a lot in Twitter API development.
#
# Iterating through timelines, user lists, direct messages, etc.
#
# In order to perform pagination we must supply a page/cursor parameter with each of our requests.
#
# The problem here is this requires a lot of boiler plate code just to manage the pagination loop.
#
# To help make pagination easier and require less code Tweepy has the Cursor object.
#
# Cursor handles all the pagination work for us behind the scene so our code can now focus entirely on processing the results.

# %% [markdown]
# ### Collecting a large number of Tweets
#
# Use special options when initializing the API. These tell it to wait while the Twitter time-limit windows elapse
#
# `api = tweepy.API(auth, wait_on_rate_limit=True)`

# %%
# NOTE: THE REDUNDANT IMPORTS AND FUNCTION DEFINITIONS IS INTENTIONAL TO MAKE THE CODE CELLS SELF CONTAINED 
import json
from logging import raiseExceptions 
import tweepy
import time
from datetime import datetime
import time
import os

# PRINT TWEEPY VERSION
print("tweepy version =",tweepy.__version__)

#----------------------
# READ API KEY FILE
#----------------------
f = open("api-keys.json")
input=json.load(f); #print(input)

# LOAD KEYS INTO API
consumer_key=input["consumer_key"]    
consumer_secret=input["consumer_secret"]    
access_token=input["access_token"]    
access_token_secret=input["access_token_secret"]    
bearer_token=input["bearer_token"]    

#----------------------
# DEFINE USEFUL FUNCTIONS
#----------------------

# DEFINE PRETTY PRINT JSON FUNCTION
def pretty_print_json(input):
    print(json.dumps(input, indent=4))

# DEFINE FUNCTION TO SAVE TWEEPY SEARCH RESULTS
#   searches=array with various tweepy search objects
#   TODO: ADD "full and sparse" mode
#          full = save all tweet data (100 tweeks ~ 1 MB  --> 100,000 ~ 1 GB)
#          sparse = only save most important info
def save_search_tweets_results(searches,info_str="",output_name="tweet-search.json"):
    # if(str(type(input)) == "<class 'tweepy.models.SearchResults'>"):
    if(str(type(searches)) == "<class 'list'>"):
        #COMBINE ALL JSONS FOR VARIOUS TWEETS INTO ON BIG JSON CALL "out"
        out={}
        out["search_info"]=info_str

        #LOOP OVER SEARCHES
        tweet_ids=[]
        k=0 #counter
        for search in searches:
            #LOOP OVER TWEETS IN SEARCH
            for i in range(0,len(search)):
                out[str(k)]=search[i]._json
                tweet_id=search[i]._json["id_str"]
                #CHECK FOR REDUNDANT TWEETS
                if tweet_id in tweet_ids:
                    print("WARNING: REPEATED TWEETS IN SAVED FILE; ID = ",tweet_id)
                tweet_ids.append(search[i]._json["id_str"])

                k+=1
            #pretty_print_json(out)

        #DELETE FILE IF IT EXIST (START FRESH)
        if os.path.exists(output_name):
            os.remove(output_name)

        #WRITE FILE
        with open(output_name, 'w') as f:
            json.dump(out, f)
    else: 
        raise RuntimeError("ERROR: Incorrect datatype")

#----------------------
# SET UP CONNECTION
#----------------------
#   Use special options when initializing the API. These tell
#   it to wait while the Twitter time-limit windows elapse
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, wait_on_rate_limit=True) 

#----------------------
# RUN SEARCH 
#----------------------

#SEARCH PARAM
query="Trump OR Mar-a-Lago OR Donald"

# NUMBER OF TWEETS TO SEARCH 
number_of_tweets=1000 
# number_of_tweets=18000*2 
# ideally use multiples of 100 for number_of_tweets
# should be able to collect 18000 tweets every 15 minutes
start_time = time.time()
max_loop_time_hrs=5

# THIS WILL KEEP DOING SEARCHES FURTHER AND FURTHER BACK IN TIME
# USING THE MAX_ID TO THE TIMELINE 
num_tweets_collected=0
searches=[]
k=0
#KEEP SEARCHING UNTIL DESIRED NUMBER OF TWEETS COLLECTED
while num_tweets_collected<number_of_tweets or (time.time()-start_time)/60./60>max_loop_time_hrs: 
    try: 
        #FIRST SEARCH
        if len(searches)==0:
            search_results = api.search_tweets(query, lang="en", count=100)
        #ADDITIONAL SEARCHES
        else:
            search_results = api.search_tweets(query, lang="en", count=100,max_id=max_id_next)

        #UPDATE PARAMETERS
        num_tweets_collected+=len(search_results)
        max_id_next=int(search_results[-1]._json["id_str"])-1

        #SAVE SEARCH RESULTS
        searches.append(search_results)

        #SAVE TEMPORARY CHECKPOINTS (DONT DO TOO OFTEN .. SLOWS CODE DOWN)
        if(k%10==0):
            print("SEARCH-"+str(k)+" COMPLETED;  TWEETS_COLLECTED=",num_tweets_collected,"; TIME (s) = ",time.time() - start_time)
        if(k%25==0):
            save_search_tweets_results(searches,output_name="tmp-snapshot.json")
            
        k+=1
    except:
        print("WARNING: twitter search failed")

    #SLEEP 5 SECONDS BEFORE NEXT REQUEST 
    if(number_of_tweets>18000):
        time.sleep(5)
    else:
        time.sleep(0.2)
        

# REPORT BASIC SEARCH INFO
print(num_tweets_collected,len(searches))
print("search time (s) =", (time.time() - start_time)) #/60.)

#TIMESTAMP SEARCH 
now = datetime.now()
dt_string = now.strftime("%Y-%m-%Y-H%H-M%M-S%S")

#----------------------
# SAVE RESULTS
#----------------------
info_str="query = "+query+"; number_of_tweets = "+str(number_of_tweets)+"; date = "+str(dt_string)
out_name=str(dt_string)+"-twitter-search.json"
save_search_tweets_results(searches,info_str=info_str,output_name=out_name)

#CLEAN-UP TEMP FILES
os.remove("tmp-snapshot.json")
# import glob
# list_to_delete=glob.glob("./*-tmp-snapshot.json")
# for file in list_to_delete:
#     os.remove(file)
# Out:
# tweepy version = 4.10.1
# SEARCH-0 COMPLETED;  TWEETS_COLLECTED= 100 ; TIME (s) =  0.6168570518493652
# SEARCH-2 COMPLETED;  TWEETS_COLLECTED= 300 ; TIME (s) =  2.197445869445801
# SEARCH-4 COMPLETED;  TWEETS_COLLECTED= 498 ; TIME (s) =  4.053128004074097
# SEARCH-6 COMPLETED;  TWEETS_COLLECTED= 695 ; TIME (s) =  5.580870866775513
# SEARCH-8 COMPLETED;  TWEETS_COLLECTED= 889 ; TIME (s) =  7.308405160903931
# SEARCH-10 COMPLETED;  TWEETS_COLLECTED= 1089 ; TIME (s) =  9.352350950241089
# 1089 11
# search time (s) = 9.952607154846191

# %% [markdown]
# ### Tweepy user objects
#
# The User object in Tweepy module contains the information about a user.
#
# Here are the list of attributes in the User object :
#
# For more see: https://www.geeksforgeeks.org/python-user-object-in-tweepy/

# %%
# returns a user object 
user_info=api.get_user(screen_name="POTUS")

# print info about user
print(json.dumps(user_info._json, indent=4, sort_keys=True))
# Out:
# {
#     "contributors_enabled": false,
#     "created_at": "Wed Jan 13 00:37:08 +0000 2021",
#     "default_profile": true,
#     "default_profile_image": false,
#     "description": "46th President of the United States, husband to @FLOTUS, proud dad & pop. Tweets may be archived: https://t.co/HDhBZB391k\nText me: (302) 404-0880",
#     "entities": {
#         "description": {
#             "urls": [
#                 {
#                     "display_url": "whitehouse.gov/privacy",
#                     "expanded_url": "http://whitehouse.gov/privacy",
#                     "indices": [
#                         98,
#                         121
#                     ],
#                     "url": "https://t.co/HDhBZB391k"
#                 }
#             ]
#         },
#         "url": {
#             "urls": [
#                 {
#                     "display_url": "WhiteHouse.gov",
#                     "expanded_url": "http://WhiteHouse.gov",
#                     "indices": [
#                         0,
#                         23
#                     ],
#                     "url": "https://t.co/MzB1JVXAkq"
#                 }
#             ]
#         }
#     },
#     "favourites_count": 1,
#     "follow_request_sent": false,
#     "followers_count": 25197453,
#     "following": false,
#     "friends_count": 12,
#     "geo_enabled": false,
#     "has_extended_profile": true,
#     "id": 1349149096909668363,
#     "id_str": "1349149096909668363",
#     "is_translation_enabled": false,
#     "is_translator": false,
#     "lang": null,
#     "listed_count": 19704,
#     "location": "",
#     "name": "President Biden",
#     "notifications": false,
#     "profile_background_color": "F5F8FA",
#     "profile_background_image_url": null,
#     "profile_background_image_url_https": null,
#     "profile_background_tile": false,
#     "profile_banner_url": "https://pbs.twimg.com/profile_banners/1349149096909668363/1660227656",
#     "profile_image_url": "http://pbs.twimg.com/profile_images/1380530524779859970/TfwVAbyX_normal.jpg",
#     "profile_image_url_https": "https://pbs.twimg.com/profile_images/1380530524779859970/TfwVAbyX_normal.jpg",
#     "profile_link_color": "1DA1F2",
#     "profile_location": null,
#     "profile_sidebar_border_color": "C0DEED",
#     "profile_sidebar_fill_color": "DDEEF6",
#     "profile_text_color": "333333",
#     "profile_use_background_image": true,
#     "protected": false,
#     "screen_name": "POTUS",
#     "status": {
#         "contributors": null,
#         "coordinates": null,
#         "created_at": "Thu Sep 08 12:53:39 +0000 2022",
#         "entities": {
#             "hashtags": [],
#             "symbols": [],
#             "urls": [
#                 {
#                     "display_url": "twitter.com/i/web/status/1\u2026",
#                     "expanded_url": "https://twitter.com/i/web/status/1567858706724929538",
#                     "indices": [
#                         117,
#                         140
#                     ],
#                     "url": "https://t.co/wOL4cZihLQ"
#                 }
#             ],
#             "user_mentions": []
#         },
#         "favorite_count": 26393,
#         "favorited": false,
#         "geo": null,
#         "id": 1567858706724929538,
#         "id_str": "1567858706724929538",
#         "in_reply_to_screen_name": null,
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "is_quote_status": false,
#         "lang": "en",
#         "place": null,
#         "retweet_count": 5788,
#         "retweeted": false,
#         "source": "<a href=\"https://www.sprinklr.com\" rel=\"nofollow\">The White House</a>",
#         "text": "Nearly 10 million new jobs have been added to the economy, a record high at this point in a presidency.\n \nWe've got\u2026 https://t.co/wOL4cZihLQ",
#         "truncated": true
#     },
#     "statuses_count": 3946,
#     "time_zone": null,
#     "translator_type": "none",
#     "url": "https://t.co/MzB1JVXAkq",
#     "utc_offset": null,
#     "verified": true,
#     "withheld_in_countries": []
# }

# %% [markdown]
# ### XTRA CODE

# %%
# #CHECK IF REPEATED SEARCH WITH SAME QUERY RESULT IN SAME OUTPUT 

# def quick_print(search_results):
#     for i in range(0,number_of_tweets):
#         try:
#             print("-------- tweet = ",i," -------")
#             print("text = ",search_results[i]._json["text"])
#             print("url = https://twitter.com/i/web/status/"+search_results[i]._json["id_str"])
#         except:
#             print("ERROR")

# #SEARCH-1
# number_of_tweets=100
# search_results = api.search_tweets("texas OR maryland", lang="en", count=number_of_tweets)
# quick_print(search_results)

# #SEARCH-2
# number_of_tweets=100
# search_results = api.search_tweets("texas OR maryland", lang="en", count=number_of_tweets)
# quick_print(search_results)
